# %%
a=(5+2)*(12/4)
print(a)
print(11/3)
print(11//3)
print(2**5)
# Out:
# 21.0
# 3.6666666666666665
# 3
# 32

# %%
bin(12)
# Out:
# '0b1100'

# %%
bin(4)
# Out:
# '0b100'

# %%
12|4
# Out:
# 12

# %%
bin(12|4)
# Out:
# '0b1100'

# %%
bin(1)
# Out:
# '0b1'

# %%
a=bin(5)
print(a)
# Out:
# 0b101

# %%
b=bin(67)
print(b)
# Out:
# 0b1000011

# %%
print(a or b)
# Out:
# 0b101

# %%
print(0b101<<0b1000011)
# Out:
# 737869762948382064640

# %%
print(0b101>>0b1000011)
# Out:
# 0

# %%
print(~0b101)
# Out:
# -6

# %%
print(~0b1000011)
# Out:
# -68
